# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("/content/dataset.csv")
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df["show_id"]=df["show_id"].str.lower()
df["type"]=df["type"].str.lower()
df["title"]=df["title"].str.lower()
df["director"]=df["director"].str.lower()
df["cast"]=df["cast"].str.lower()
df["country"]=df["country"].str.lower()
df["rating"]=df["rating"].str.lower()
df["listed_in"]=df["listed_in"].str.lower()
df["description"]=df["description"].str.lower()

# %%
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    movie  dick johnson is dead  kirsten johnson
# 1      s2  tv show         blood & water              NaN
# 2      s3  tv show             ganglands  julien leclercq
#
#                                                 cast        country  \
# 0                                                NaN  united states
# 1  ama qamata, khosi ngema, gail mabalane, thaban...   south africa
# 2  sami bouajila, tracy gotoas, samuel jouy, nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  pg-13     90 min
# 1  September 24, 2021          2021  tv-ma  2 Seasons
# 2  September 24, 2021          2021  tv-ma   1 Season
#
#                                            listed_in  \
# 0                                      documentaries
# 1    international tv shows, tv dramas, tv mysteries
# 2  crime tv shows, international tv shows, tv act...
#
# ...

# %%
df["show_id"]=df["show_id"].str.strip()
df["type"]=df["type"].str.strip()
df["title"]=df["title"].str.strip()
df["director"]=df["director"].str.strip()
df["cast"]=df["cast"].str.strip()
df["country"]=df["country"].str.strip()
df["rating"]=df["rating"].str.strip()
df["listed_in"]=df["listed_in"].str.strip()
df["description"]=df["description"].str.strip()

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    movie  dick johnson is dead  kirsten johnson
# 1      s2  tv show         blood & water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  united states
# 1  ama qamata, khosi ngema, gail mabalane, thaban...   south africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  pg-13     90 min
# 1  September 24, 2021          2021  tv-ma  2 Seasons
#
#                                          listed_in  \
# 0                                    documentaries
# 1  international tv shows, tv dramas, tv mysteries
#
#                                          description
# 0  as her father nears the end of his life, filmm...
# 1  after crossing paths at a party, a cape town t...

# %%
df.rename(columns={"type":"types","cast":"casts"})
# Out:
#      show_id    types                  title         director  \
# 0         s1    movie   dick johnson is dead  kirsten johnson
# 1         s2  tv show          blood & water              NaN
# 2         s3  tv show              ganglands  julien leclercq
# 3         s4  tv show  jailbirds new orleans              NaN
# 4         s5  tv show           kota factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    movie                 zodiac    david fincher
# 8803   s8804  tv show            zombie dumb              NaN
# 8804   s8805    movie             zombieland  ruben fleischer
# 8805   s8806    movie                   zoom     peter hewitt
# 8806   s8807    movie                 zubaan      mozez singh
#
#                                                   casts        country  \
# 0                                                   NaN  united states
# 1     ama qamata, khosi ngema, gail mabalane, thaban...   south africa
# ...

# %%
#dropping_duplicates
df.drop_duplicates(inplace=True)

# %%
df["added_date"]=pd.to_datetime(df["date_added"],format="%B %d, %Y",errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  added_date    8709 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 894.6+ KB

# %%
# Find rows where added_date is NaT but date_added is not NaN
unparsed_dates = df[df['added_date'].isna() & df['date_added'].notna()]

# Display some of the original date_added values that were not parsed
if not unparsed_dates.empty:
    print("Sample of date_added values that were not parsed:")
    display(unparsed_dates['date_added'].sample(min(10, len(unparsed_dates))))
else:
    print("All non-null date_added values were successfully parsed.")
# Out:
# Sample of date_added values that were not parsed:
# 6678      February 24, 2018
# 7896           May 18, 2017
# 8315       February 1, 2017
# 7705         August 4, 2017
# 8064       February 1, 2015
# 7679          July 20, 2018
# 6304          July 26, 2019
# 7850      December 15, 2017
# 7457     September 16, 2018
# 8422       November 1, 2017
# Name: date_added, dtype: object

# %%
df['date_added'] = df['date_added'].str.strip()
df["added_date"] = pd.to_datetime(df["date_added"], format="%B %d, %Y", errors='coerce')

# Check how many values are still NaT after stripping whitespace
print(f"Number of NaT values in 'added_date' after stripping whitespace: {df['added_date'].isna().sum()}")

# Display info to see the non-null counts
display(df.info())
# Out:
# Number of NaT values in 'added_date' after stripping whitespace: 10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  added_date    8797 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 894.6+ KB
# None

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  added_date    8797 non-null   datetime64[ns]
#  13  added_month   8797 non-null   float64
#  14  added_year    8797 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(11)
# memory usage: 1.0+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  added_date    8797 non-null   datetime64[ns]
#  13  added_month   8797 non-null   float64
#  14  added_year    8797 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(11)
# memory usage: 1.0+ MB

# %%
# Calculate the number of null values in each row
null_counts_per_row = df.isnull().sum(axis=1)
# print(null_counts_per_row)

# Identify rows with more than 5 null values
rows_to_drop = null_counts_per_row[null_counts_per_row > 3].index
#print(rows_to_drop)

# Drop the identified rows
df_cleaned = df.drop(rows_to_drop)

# Display the shape of the original and cleaned DataFrame to show the number of rows dropped
print(f"Original DataFrame shape: {df.shape}")
print(f"DataFrame shape after dropping rows with more than 5 null values: {df_cleaned.shape}")
# Out:
# Original DataFrame shape: (8807, 15)
# DataFrame shape after dropping rows with more than 5 null values: (8797, 15)

# %%
 print(len(rows_to_drop))
# Out:
# 10

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8797 entries, 0 to 8806
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8797 non-null   object
#  1   type          8797 non-null   object
#  2   title         8797 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7972 non-null   object
#  5   country       7967 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8797 non-null   int64
#  8   rating        8793 non-null   object
#  9   duration      8794 non-null   object
#  10  listed_in     8797 non-null   object
#  11  description   8797 non-null   object
#  12  added_date    8797 non-null   datetime64[ns]
#  13  added_month   8797 non-null   float64
#  14  added_year    8797 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df_cleaned.isnull().sum()
# Out:
# show_id         0
# types           0
# title           0
# director        0
# casts           0
# country         0
# date_added      0
# release_year    0
# rating          4
# duration        3
# listed_in       0
# description     0
# added_date      0
# added_month     0
# added_year      0
# dtype: int64

# %%
df_cleaned.rename(columns={"type":"types","cast":"casts"},inplace=True)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8797 entries, 0 to 8806
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8797 non-null   object
#  1   types         8797 non-null   object
#  2   title         8797 non-null   object
#  3   director      8797 non-null   object
#  4   casts         7972 non-null   object
#  5   country       7967 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8797 non-null   int64
#  8   rating        8793 non-null   object
#  9   duration      8794 non-null   object
#  10  listed_in     8797 non-null   object
#  11  description   8797 non-null   object
#  12  added_date    8797 non-null   datetime64[ns]
#  13  added_month   8797 non-null   float64
#  14  added_year    8797 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df_cleaned['director'].fillna('Unknown', inplace=True)

# Checking the number of nulls in the 'director' column after filling
print(f"Number of null values in 'director' column after filling: {df_cleaned['director'].isnull().sum()}")
# Out:
# Number of null values in 'director' column after filling: 0
# <ipython-input-49-8c4a0ea4831d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned['director'].fillna('Unknown', inplace=True)

# %%
# do the same for the cast and country
df_cleaned['casts'].fillna('Unknown', inplace=True)
df_cleaned['country'].fillna('Unknown', inplace=True)
# Out:
# <ipython-input-54-35eaf865e2e1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned['casts'].fillna('Unknown', inplace=True)
# <ipython-input-54-35eaf865e2e1>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
#dropping rows with null values in  rating and duration
df_cleaned.dropna(subset=["rating","duration"],inplace=True)

# %%
df_cleaned.isnull().sum()
# Out:
# show_id         0
# types           0
# title           0
# director        0
# casts           0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# added_date      0
# added_month     0
# added_year      0
# dtype: int64

# %%
display(df_cleaned.isnull().sum())
# Out:
# show_id         0
# types           0
# title           0
# director        0
# casts           0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# added_date      0
# added_month     0
# added_year      0
# dtype: int64

# %%
df.to_csv("cleaned_dataset.csv")

# %%
display(df.dtypes)
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# added_date      datetime64[ns]
# added_month            float64
# added_year             float64
# dtype: object

# %%
how to

# %%
# Example: Dropping a single column named 'description'
# Make sure to assign the result back to your DataFrame
df_cleaned = df_cleaned.drop(columns=["date_added"])

# Or, to drop multiple columns:
# df = df.drop(columns=['column_name1', 'column_name2'])

# Display the columns to confirm the drop
display(df_cleaned.columns)
# Out:
# Index(['show_id', 'types', 'title', 'director', 'casts', 'country',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'added_date', 'added_month', 'added_year'],
#       dtype='object')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 0 to 8806
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   types         8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   casts         8790 non-null   object
#  5   country       8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
#  10  description   8790 non-null   object
#  11  added_date    8790 non-null   datetime64[ns]
#  12  added_month   8790 non-null   float64
#  13  added_year    8790 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(10)
# memory usage: 1.0+ MB

# %%
df_cleaned['added_month'] = df_cleaned['added_month'].astype(int)
df_cleaned['added_year'] = df_cleaned['added_year'].astype(int)

display(df_cleaned.dtypes)
# Out:
# show_id                 object
# types                   object
# title                   object
# director                object
# casts                   object
# country                 object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# added_date      datetime64[ns]
# added_month              int64
# added_year               int64
# dtype: object

# %%
df_cleaned.head()
# Out:
#   show_id    types                  title         director  \
# 0      s1    movie   dick johnson is dead  kirsten johnson
# 1      s2  tv show          blood & water          Unknown
# 2      s3  tv show              ganglands  julien leclercq
# 3      s4  tv show  jailbirds new orleans          Unknown
# 4      s5  tv show           kota factory          Unknown
#
#                                                casts        country  \
# 0                                            Unknown  united states
# 1  ama qamata, khosi ngema, gail mabalane, thaban...   south africa
# 2  sami bouajila, tracy gotoas, samuel jouy, nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  mayur more, jitendra kumar, ranjan raj, alam k...          india
#
#    release_year rating   duration  \
# 0          2020  pg-13     90 min
# 1          2021  tv-ma  2 Seasons
# 2          2021  tv-ma   1 Season
# 3          2021  tv-ma   1 Season
# ...
